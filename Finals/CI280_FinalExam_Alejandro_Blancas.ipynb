# %% [markdown]
# # East-West University
#
# # CI280 Final Exam - 2020 Fall  (100 points)
#
# # Student Name: Alejandro Blancas
#
# # Student ID: 20319

# %% [markdown]
# ### Real Estate Data  Analysis

# %%
# %matplotlib inline
import random
import pandas as pd
import matplotlib.pyplot as plt

plt.rc('figure', figsize=(10, 8))

# %%
# limiting the display rows
pd.set_option('display.max_rows', 8)

# %%
df = pd.read_csv('data/RealEstate.csv')
print(realEstate.shape)
df
# Out:
# (81, 8)
#     Trans_No               Address            City Selling_Agent  \
# 0          1     8687 Kenwood Road     Cedar Hills     Hernandez
# 1          2    11 West Oak Circle   American Fork         Carey
# 2          3   314 Timp View Drive   American Fork      Goodrich
# 3          4  614 West Cedar Drive            Lehi          Lugo
# ..       ...                   ...             ...           ...
# 77        78        123 Oak Avenue   American Fork         Carey
# 78        79          600 Ivy Lane  Eagle Mountain        Pijuan
# 79        80        144 Oak Avenue   American Fork      Goodrich
# 80        81    1600 Reeves Street     Cedar Hills        Reuter
#
#     Asking_Price  Selling_Price Listing_Date  Sale_Date
# 0         725000         645250     4/1/2018  6/16/2018
# 1         350000         340000     4/1/2018  5/15/2018
# 2         418000         400000     4/1/2018   6/1/2018
# 3         215800         200000     4/1/2018  5/25/2018
# ...

# %% [markdown]
# # Part A: Basic Dataframe ( 50 pts)

# %%
import random
number = random.randint(0,10000)

print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')

# Problem 1 ( 3 = 3 = 6 pts)

# Display datafrome realEstate column names
print('Display columns by each line')
print('---------------------------------')
names = df.columns
for col in df.columns:
    print(col)
# Out:
# Alejandro Blancas , id: 20319  6986
# ------------------------------
#
# Display columns by each line
# ---------------------------------
# Trans_No
# Address
# City
# Selling_Agent
# Asking_Price
# Selling_Price
# Listing_Date
# Sale_Date

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')

# Problem 2. (3 + 3 = 6 points)
# Diplay DataFrame realEstate's three columns:  Trans_No , City, Asking_Price
res = df[['Trans_No', 'City', 'Asking_Price']]
res
# Out:
# Alejandro Blancas , id: 20319  7229
# ------------------------------
#     Trans_No            City  Asking_Price
# 0          1     Cedar Hills        725000
# 1          2   American Fork        350000
# 2          3   American Fork        418000
# 3          4            Lehi        215800
# ..       ...             ...           ...
# 77        78   American Fork        400000
# 78        79  Eagle Mountain        339999
# 79        80   American Fork        380500
# 80        81     Cedar Hills        245900
#
# [81 rows x 3 columns]

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')


# Problem 3. ( 8 points)
# Show all realestates in the city Cedar Hills or Eagle Mountain

res = df[(df['City']=='Cedar Hills') | (df['City']=='Eagle Mountain')]
res
# Out:
# Alejandro Blancas , id: 20319  3615
# ------------------------------
#     Trans_No                   Address            City Selling_Agent  \
# 0          1         8687 Kenwood Road     Cedar Hills     Hernandez
# 17        18  9876 South Sunset Avenue  Eagle Mountain     Hernandez
# 21        22  9000 South Sunset Avenue  Eagle Mountain          Lugo
# 22        23  8432 South Sunset Avenue  Eagle Mountain        Minkus
# ..       ...                       ...             ...           ...
# 73        74              425 East Oak  Eagle Mountain       Bethune
# 76        77              516 East Oak  Eagle Mountain        Pijuan
# 78        79              600 Ivy Lane  Eagle Mountain        Pijuan
# 80        81        1600 Reeves Street     Cedar Hills        Reuter
#
#     Asking_Price  Selling_Price Listing_Date  Sale_Date
# 0         725000         645250     4/1/2018  6/16/2018
# 17        300000         300000    4/18/2018  4/30/2018
# ...

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')


# Problem 4. (8 points)
# List all realestates sold by agent Carey and Asking_Price is over $300,000
total_sold = df[(df['Selling_Agent']=='Carey') & (df.Asking_Price > 300000)]
total_sold
# Out:
# Alejandro Blancas , id: 20319  2054
# ------------------------------
#     Trans_No                  Address            City Selling_Agent  \
# 1          2       11 West Oak Circle   American Fork         Carey
# 5          6         7 Kingston Court          Alpine         Carey
# 13        14  143 North Mountain View   American Fork         Carey
# 33        34     11971 SW 269 Terrace     Cedar Hills         Carey
# ..       ...                      ...             ...           ...
# 59        60     34 West Oakley Drive   American Fork         Carey
# 62        63      160 West 5th Street  Eagle Mountain         Carey
# 72        73          10 Vestal Drive     Cedar Hills         Carey
# 77        78           123 Oak Avenue   American Fork         Carey
#
#     Asking_Price  Selling_Price Listing_Date   Sale_Date
# 1         350000         340000     4/1/2018   5/15/2018
# 5         500000         465000     4/3/2018   6/10/2018
# ...

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')
# Problem 5. ( 4+4 =8 points)
      
# Display all Cities and display one city in one line   
names = df['City'].unique()

print('Display each city in a line')
print('-----------------------------')
for name in names:
    if pd.notnull(name):
        print(name)
# Out:
# Alejandro Blancas , id: 20319  9541
# ------------------------------
#
# Display each city in a line
# -----------------------------
# Cedar Hills
# American Fork
# Lehi
# Alpine
# Eagle Mountain

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')


# Problem 6. (14 points)
# A) Show the total number of realestate listed in the dataset 
# C) Display the highest asking price of realestate  
# B) Display the average selling price, and average asking prince
# D) Compute the percentage of average selling price to asking price 
realTotal = df['Trans_No'].max()
highPrice = df['Asking_Price'].max()
avgSell = df['Selling_Price'].mean()
avgAsk = df['Asking_Price'].mean()
a_num = avgSell/avgAsk
percent = "{:.2%}".format(a_num)
print('\nThe total number of realestate:',realTotal)
print('\nThe highest asking price: $', highPrice)
print('Average Selling Price: $\n')
print(format(avgSell, '.0f'))
print('\nAverage Selling Price: $\n', )
print(format(avgAsk,'.0f'))
print('\nThe Percentage of Average Selling price to Average Asking price:',percent)
# Out:
# Alejandro Blancas , id: 20319  3551
# ------------------------------
#
#
# The total number of realestate: 81
#
# The highest asking price: $ 1500120
# Average Selling Price: $
#
# 354041
#
# Average Selling Price: $
#
# 390111
#
# The Percentage of Average Selling price to Average Asking price: 90.75%

# %% [markdown]
# # Part B:  (50 points)

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')
# Problem 1. ( 8 pts)
# Sorting the realestate data by city and Asking price in ascending oreder
df.sort_values(by=['City','Asking_Price'],ascending = False)
# Out:
# Alejandro Blancas , id: 20319  4612
# ------------------------------
#     Trans_No                Address    City Selling_Agent  Asking_Price  \
# 38        39    2448 Woodacres Road    Lehi     Hernandez        450000
# 20        21     1900 Glenview Road    Lehi     Hernandez        325000
# 6          7   618 West Cedar Drive    Lehi          Lugo        300000
# 60        61           30 Kent Road    Lehi       Bethune        259900
# ..       ...                    ...     ...           ...           ...
# 49        50    605 Reservoir Drive  Alpine        Reuter        310000
# 8          9     1370 Pinellas Road  Alpine          Lugo        219000
# 64        65    520 E Spring Street  Alpine        Minkus        189900
# 47        48  81 Island Drive South  Alpine       Bethune        147800
#
#     Selling_Price Listing_Date  Sale_Date
# 38         382500     5/5/2018  6/16/2018
# 20         302250    4/28/2018   6/1/2018
# 6          290000     4/3/2018   6/1/2018
# ...

# %%
number = random.randint(0,10000)
print("Alejandro Blancas , id: 20319 ", number )
print('------------------------------\n')

# Problem 2. ( 8 pts)
# List three lowest asking price realestate sold in City Lehi
price = df[df.City == 'Lehi'].sort_values(by='Asking_Price',ascending = False)
price

res = price.tail(3)
res
# Out:
# Alejandro Blancas , id: 20319  170
# ------------------------------
#     Trans_No             Address  City Selling_Agent  Asking_Price  \
# 75        76    103 Jasper Drive  Lehi       Bethune        165900
# 9         10  1971 Glenview Road  Lehi        Minkus        165000
# 12        13   10995 SW 88 Court  Lehi      Goodrich        110000
#
#     Selling_Price Listing_Date  Sale_Date
# 75         159264    6/29/2018   9/6/2018
# 9          156750    4/12/2018  6/12/2018
# 12         106000    4/12/2018   7/3/2018

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------\n')

#  Problem 3. ( 10 pts)

#  Show the average selling price of real estate sold by agent Goodrich
#  Is its average selling price above or below the average selling price of all realstates?
avgGood = df[df.Selling_Agent=='Goodrich'].Selling_Price.mean()
avgAll = df['Selling_Price'].mean()
    
print('Average Selling Price by Agent Goodrich is:  $' )
print(format(avgGood,'.2f'))
print('Average Selling Price by all agents is:  $' )
print(format(avgAll,'.2f'))

if avgGood > avgAll:
    print('The average selling price from agent Goodrich is above')
else:
    print('The average selling price from agent Goodrich is below')
# Out:
# You name , id:  4405
# ------------------------------
#
# Average Selling Price by Agent Goodrich is:  $
# 344992.86
# Average Selling Price by all agents is:  $
# 354040.86
# The average selling price from agent Goodrich is below

# %%
number = random.randint(0,10000)
print("You name , id: ", number )
print('------------------------------')


# Problem 4. ( 14 pts)
# Display and plot the average Asking Price in each city in ascending ording. 
res1 = df['Asking_Price'].groupby(df.City).mean()
total = df.sort_values(by='City', ascending = False)
res1.plot(kind='bar')
plt.title('The average Asking Price in Each City')
# Out:
# You name , id:  1417
# ------------------------------
# Text(0.5, 1.0, 'The average Asking Price in Each City')

# %%
# Problem 5. ( 10 pt)
# Show the real estate number of each agent,
# and sorted by the agent name
# And plot the result as bar chart
res1 = df['Trans_No'].groupby(df.Selling_Agent).count()
total = df.sort_values(by='Selling_Agent', ascending = False)
res1.plot(kind='bar')
plt.title('Number of Realstates sold by Each Agent')
# Out:
# Text(0.5, 1.0, 'Number of Realstates sold by Each Agent')
